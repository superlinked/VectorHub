# %% [markdown]
# # Why You Don't Need Re-Ranking: Superlinked Demo
# ## Comparing Traditional vs Superlinked Approach
#
# This notebook accompanies the article ["Why You Don’t Need Re-Ranking: Understanding the Superlinked Vector Layer"](https://docs.google.com/document/d/13wjmFAeRcP1Fhj_Tog9qHBavev5rKnAFYbBWRmlOwQo/edit?tab=t.0).
# It demonstrates:
#  - Traditional re-ranking approach with hybrid scoring
#  - Superlinked's unified vector layer approach
#  - Performance comparison using a product search use case

# %% [markdown]
# # Setup & Installation

# %%
# Install required packages
# !pip install rerankers
# !pip install superlinked
# Out:
# Requirement already satisfied: rerankers in /usr/local/lib/python3.11/dist-packages (0.9.1.post1)
# Requirement already satisfied: superlinked in /usr/local/lib/python3.11/dist-packages (23.2.0)
# Requirement already satisfied: Deprecated<2.0.0,>=1.2.18 in /usr/local/lib/python3.11/dist-packages (from superlinked) (1.2.18)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.7 in /usr/local/lib/python3.11/dist-packages (from superlinked) (3.11.15)
# Requirement already satisfied: asgi-correlation-id<5.0.0,>=4.3.4 in /usr/local/lib/python3.11/dist-packages (from superlinked) (4.3.4)
# Requirement already satisfied: beartype<0.21.0,>=0.17.2 in /usr/local/lib/python3.11/dist-packages (from superlinked) (0.20.2)
# Requirement already satisfied: cachetools<6.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from superlinked) (5.5.2)
# Requirement already satisfied: certifi<2026.0.0,>=2024.7.4 in /usr/local/lib/python3.11/dist-packages (from superlinked) (2025.4.26)
# Requirement already satisfied: filelock<4.0.0,>=3.16.1 in /usr/local/lib/python3.11/dist-packages (from superlinked) (3.18.0)
# Requirement already satisfied: furl<3.0.0,>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from superlinked) (2.1.4)
# Requirement already satisfied: graphviz<0.21.0,>=0.20.1 in /usr/local/lib/python3.11/dist-packages (from superlinked) (0.20.3)
# Requirement already satisfied: infinity-client<0.0.77,>=0.0.76 in /usr/local/lib/python3.11/dist-packages (from superlinked) (0.0.76)
# Requirement already satisfied: instructor<2.0.0,>=1.3.7 in /usr/local/lib/python3.11/dist-packages (from superlinked) (1.8.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from superlinked) (3.1.6)
# Requirement already satisfied: modal==0.74.45 in /usr/local/lib/python3.11/dist-packages (from superlinked) (0.74.45)
# Requirement already satisfied: nltk<4.0.0,>=3.9.1 in /usr/local/lib/python3.11/dist-packages (from superlinked) (3.9.1)
# Requirement already satisfied: numpy<2.0.0,>=1.25.2 in /usr/local/lib/python3.11/dist-packages (from superlinked) (1.26.4)
# Requirement already satisfied: open_clip_torch<2.33.0 in /usr/local/lib/python3.11/dist-packages (from superlinked) (2.32.0)
# Requirement already satisfied: pandas<3.0.0,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from superlinked) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in /usr/local/lib/python3.11/dist-packages (from superlinked) (2.11.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from superlinked) (2.9.1)
# Requirement already satisfied: redisvl<0.7.0,>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from superlinked) (0.6.0)
# Requirement already satisfied: requests<3.0,>=2.31 in /usr/local/lib/python3.11/dist-packages (from superlinked) (2.32.3)
# Requirement already satisfied: sentence-transformers==4.1.0 in /usr/local/lib/python3.11/dist-packages (from superlinked) (4.1.0)
# Requirement already satisfied: structlog<26.0,>=24.4 in /usr/local/lib/python3.11/dist-packages (from superlinked) (25.3.0)
# Requirement already satisfied: types-Deprecated>=1.2.15 in /usr/local/lib/python3.11/dist-packages (from superlinked) (1.2.15.20250304)
# Requirement already satisfied: types-cachetools<6.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from superlinked) (5.5.0.20240820)
# Requirement already satisfied: typing_extensions>=3.10.0.2 in /usr/local/lib/python3.11/dist-packages (from superlinked) (4.13.2)
# Requirement already satisfied: click>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (8.1.8)
# Requirement already satisfied: grpclib==0.4.7 in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (0.4.7)
# Requirement already satisfied: protobuf!=4.24.0,<6.0,>=3.19 in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (5.29.4)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (13.9.4)
# Requirement already satisfied: synchronicity~=0.9.10 in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (0.9.12)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (0.10.2)
# Requirement already satisfied: typer>=0.9 in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (0.15.3)
# Requirement already satisfied: types-certifi in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (2021.10.8.3)
# Requirement already satisfied: types-toml in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (0.10.8.20240310)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.11/dist-packages (from modal==0.74.45->superlinked) (1.0.5)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==4.1.0->superlinked) (4.51.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==4.1.0->superlinked) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==4.1.0->superlinked) (2.6.0+cu124)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==4.1.0->superlinked) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==4.1.0->superlinked) (1.15.2)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==4.1.0->superlinked) (0.30.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from sentence-transformers==4.1.0->superlinked) (11.2.1)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from grpclib==0.4.7->modal==0.74.45->superlinked) (4.2.0)
# Requirement already satisfied: multidict in /usr/local/lib/python3.11/dist-packages (from grpclib==0.4.7->modal==0.74.45->superlinked) (6.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.7->superlinked) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.7->superlinked) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.7->superlinked) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.7->superlinked) (1.6.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.7->superlinked) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.11.7->superlinked) (1.20.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from asgi-correlation-id<5.0.0,>=4.3.4->superlinked) (24.2)
# Requirement already satisfied: starlette>=0.18 in /usr/local/lib/python3.11/dist-packages (from asgi-correlation-id<5.0.0,>=4.3.4->superlinked) (0.46.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated<2.0.0,>=1.2.18->superlinked) (1.17.2)
# Requirement already satisfied: six>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from furl<3.0.0,>=2.1.3->superlinked) (1.17.0)
# Requirement already satisfied: orderedmultidict>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from furl<3.0.0,>=2.1.3->superlinked) (1.0.1)
# Requirement already satisfied: httpx<0.28.0,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from infinity-client<0.0.77,>=0.0.76->superlinked) (0.27.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from infinity-client<0.0.77,>=0.0.76->superlinked) (2.9.0.post0)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (0.16)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (0.8.2)
# Requirement already satisfied: openai<2.0.0,>=1.52.0 in /usr/local/lib/python3.11/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (1.76.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (2.33.2)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from instructor<2.0.0,>=1.3.7->superlinked) (9.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.4->superlinked) (3.0.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.9.1->superlinked) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk<4.0.0,>=3.9.1->superlinked) (2024.11.6)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from open_clip_torch<2.33.0->superlinked) (0.21.0+cu124)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from open_clip_torch<2.33.0->superlinked) (6.3.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from open_clip_torch<2.33.0->superlinked) (0.5.3)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from open_clip_torch<2.33.0->superlinked) (1.0.15)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.0.3->superlinked) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3.0.0,>=2.0.3->superlinked) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.6.4->superlinked) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.6.4->superlinked) (0.4.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->superlinked) (1.1.0)
# Requirement already satisfied: jsonpath-ng<2.0.0,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from redisvl<0.7.0,>=0.4.1->superlinked) (1.7.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from redisvl<0.7.0,>=0.4.1->superlinked) (0.4.1)
# Requirement already satisfied: python-ulid<4.0.0,>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from redisvl<0.7.0,>=0.4.1->superlinked) (3.0.0)
# Requirement already satisfied: pyyaml<7.0,>=5.4 in /usr/local/lib/python3.11/dist-packages (from redisvl<0.7.0,>=0.4.1->superlinked) (6.0.2)
# Requirement already satisfied: redis<6.0,>=5.0 in /usr/local/lib/python3.11/dist-packages (from redisvl<0.7.0,>=0.4.1->superlinked) (5.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->superlinked) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->superlinked) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.31->superlinked) (2.4.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.20.0->infinity-client<0.0.77,>=0.0.76->superlinked) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.20.0->infinity-client<0.0.77,>=0.0.76->superlinked) (1.0.9)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.20.0->infinity-client<0.0.77,>=0.0.76->superlinked) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.20.0->infinity-client<0.0.77,>=0.0.76->superlinked) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers==4.1.0->superlinked) (2025.3.2)
# Requirement already satisfied: ply in /usr/local/lib/python3.11/dist-packages (from jsonpath-ng<2.0.0,>=1.5.0->redisvl<0.7.0,>=0.4.1->superlinked) (3.11)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2.0.0,>=1.52.0->instructor<2.0.0,>=1.3.7->superlinked) (1.9.0)
# Requirement already satisfied: PyJWT~=2.9.0 in /usr/local/lib/python3.11/dist-packages (from redis<6.0,>=5.0->redisvl<0.7.0,>=0.4.1->superlinked) (2.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12.0.0->modal==0.74.45->superlinked) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12.0.0->modal==0.74.45->superlinked) (2.19.1)
# Requirement already satisfied: sigtools>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from synchronicity~=0.9.10->modal==0.74.45->superlinked) (4.0.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (3.4.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers==4.1.0->superlinked) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers==4.1.0->superlinked) (0.21.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9->modal==0.74.45->superlinked) (1.5.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->open_clip_torch<2.33.0->superlinked) (0.2.13)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->sentence-transformers==4.1.0->superlinked) (3.6.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3.1.0->grpclib==0.4.7->modal==0.74.45->superlinked) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.11/dist-packages (from h2<5,>=3.1.0->grpclib==0.4.7->modal==0.74.45->superlinked) (4.1.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->modal==0.74.45->superlinked) (0.1.2)

# %%
# Imports
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
from rerankers import Reranker
from superlinked import framework as sl

# %% [markdown]
# # Dataset Overview
# We'll use a simple electronics products dataset with:
#
# ### **Text descriptions**
#
# *   Numerical fields (price, rating)
# *   Categorical field (product category)

# %%
# Sample product data
products = [
    {
        "id": "p1",
        "title": "Premium Wireless Headphones",
        "description": "High-end wireless headphones with active noise cancellation (ANC), 30hr battery. Original price $350, now discounted to $199.",
        "price": 199,
        "rating": 4.8,
        "category": "electronics"
    },
    {
        "id": "p2",
        "title": "Budget Noise-Canceling Earbuds",
        "description": "Affordable wireless earbuds with basic noise cancellation. 20hr battery. Ideal for casual use.",
        "price": 89,
        "rating": 4.2,
        "category": "electronics"
    },
    {
        "id": "p3",
        "title": "Studio-Grade ANC Headphones",
        "description": "Professional noise-canceling headphones with Hi-Res audio. Priced at $210.",
        "price": 210,
        "rating": 4.7,
        "category": "electronics"
    }
]

# %% [markdown]
# ## Traditional Approach with Re-Ranking
# ### Implementation Steps:
#
# 1. Text embedding with Sentence Transformers
# 2. Neural re-ranking with mxbai model
# 3. Manual hybrid scoring with metadata
# 4. Post-filtering on price

# %%
# User query and embedding with SentenceTransformer
query_text = "Find affordable wireless headphones with noise cancellation under $200 and high ratings"

model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
embeddings = model.encode([p["description"] for p in products])

# %%
# Initialize reranker
ranker = Reranker("mixedbread-ai/mxbai-rerank-large-v1")
reranked = ranker.rank(
    query=query_text,
    docs=[p["description"] for p in products],
    doc_ids=[p["id"] for p in products]
)
# Out:
# Warning: Model type could not be auto-mapped with the defaults list. Defaulting to TransformerRanker.
# If your model is NOT intended to be ran as a one-label cross-encoder, please reload it and specify the model_type! Otherwise, you may ignore this warning. You may specify `model_type='cross-encoder'` to suppress this warning in the future.
# Loading TransformerRanker model mixedbread-ai/mxbai-rerank-large-v1 (this message can be suppressed by setting verbose=0)
# No device set
# Using device cpu
# No dtype set
# Using dtype torch.float32
# Loaded model mixedbread-ai/mxbai-rerank-large-v1
# Using device cpu.
# Using dtype torch.float32.

# %%
# Reranker-based hybrid ranking with hard price filtering
def process_traditional_results(reranked_output, max_price=200):
    results = []
    for doc in reranked_output.top_k(len(products)):
        product = next(p for p in products if p["id"] == doc.doc_id)

        # Hard filter on price
        if product["price"] > max_price:
            continue

        # Combine reranker score with rating
        combined_score = (doc.score * 0.6) + (product["rating"] / 5 * 0.4)

        results.append({
            "title": product["title"],
            "price": product["price"],
            "rating": product["rating"],
            "reranker_score": doc.score,
            "final_score": combined_score
        })

    return pd.DataFrame(results).sort_values("final_score", ascending=False)

# Display traditional results
traditional_df = process_traditional_results(reranked)
print("\nTraditional Approach Results:")
display(traditional_df)
# Out:
# Traditional Approach Results:
#                             title  price  rating  reranker_score  final_score
# 0     Premium Wireless Headphones    199     4.8        2.262444     1.741466
# 1  Budget Noise-Canceling Earbuds     89     4.2        1.319153     1.127492

# %% [markdown]
# ---
#
# ## Superlinked Unified Approach
#
# Now let's implement the same product search using Superlinked's unified vector layer.
#
# Unlike the traditional approach:
# - We **don’t manually embed** product descriptions.
# - We **don’t re-rank** results post-search.
# - All relevant features (text, price, rating, category) are encoded into **a unified index**.
#
# Superlinked automatically handles embeddings at ingestion (`source.put(...)`) using the similarity spaces defined in the schema.

# %%
# Define product schema for Superlinked
@sl.schema
class Product:
    id: sl.IdField
    title: sl.String
    description: sl.String
    price: sl.Integer
    rating: sl.Float
    category: sl.String

product = Product()

# Define similarity spaces
text_space = sl.TextSimilaritySpace(
    text=product.description,
    model="sentence-transformers/all-mpnet-base-v2"
)

price_space = sl.NumberSpace(
    number=product.price,
    mode=sl.Mode.MINIMUM,
    min_value=0,
    max_value=500
)

rating_space = sl.NumberSpace(
    number=product.rating,
    mode=sl.Mode.MAXIMUM,
    min_value=0,
    max_value=5
)

category_space = sl.CategoricalSimilaritySpace(
    category_input=product.category,
    categories=["electronics", "fashion", "home", "sports", "books"],
    negative_filter=-1.0,
    uncategorized_as_category=False
)

# %%
# Create index with filterable fields
product_index = sl.Index(
    [text_space, price_space, rating_space, category_space],
    fields=[product.category, product.price]
)

# Load source and run executor
source = sl.InMemorySource(product)
executor = sl.InMemoryExecutor(sources=[source], indices=[product_index])
app = executor.run()
source.put(products)

# %%
# Unified multimodal query with dynamic weights and hard filters
query = (
    sl.Query(product_index, weights={
        text_space: 0.5,
        price_space: 0.3,
        rating_space: 0.2
    })
    .find(product)
    .similar(text_space.text, query_text)
    .filter(product.category == "electronics")
    .filter(product.price <= 200)
    .select_all()
)

# Execute query
result = app.query(query)

# Display results as DataFrame
sl.PandasConverter.to_pandas(result)
# Out:
#                             title  \
# 0     Premium Wireless Headphones
# 1  Budget Noise-Canceling Earbuds
#
#                                          description  price  rating  \
# 0  High-end wireless headphones with active noise...    199     4.8
# 1  Affordable wireless earbuds with basic noise c...     89     4.2
#
#       category  id  similarity_score
# 0  electronics  p1          0.731401
# 1  electronics  p2          0.731056

# %% [markdown]
# ## Key Advantages Demonstrated:
#
# 1. **Single unified index** combining text, numbers and categories
# 2. **Pre-search filtering** eliminates irrelevant results early
# 3. **Dynamic weighting** adjusts importance without re-embedding
# 4. **Simpler code structure** with native multimodal support
